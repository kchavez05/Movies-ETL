# %%
import pandas as pd

# %%
kaggle_metadata = pd.read_csv(f'movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'ratings.csv')

# %%
wiki_movies_raw_df = pd.DataFrame(kaggle_metadata)
ratings_raw_df = pd.DataFrame(ratings)

# %%
wiki_movies_raw_df.sample(n=5)
# Out:
#        adult belongs_to_collection    budget  \
# 11720  False                   NaN  16000000
# 29673  False                   NaN         0
# 3892   False                   NaN         6
# 36581  False                   NaN         0
# 572    False                   NaN         0
#
#                                                   genres  \
# 11720  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 29673  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 3892   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 36581                [{'id': 99, 'name': 'Documentary'}]
# 572    [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...
#
#                                      homepage      id    imdb_id  \
# 11720  http://video.movies.go.com/thelookout/    8270  tt0427470
# 29673                                     NaN   15165  tt0426955
# 3892                                      NaN   12509  tt0183659
# 36581                                     NaN  195732  tt0341378
# ...

# %%
ratings_raw_df.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 12543317  130147   143385     3.5  1491158097
# 8318061    85725     1242     3.0  1014342347
# 2697714    27963   132140     2.5  1452270375
# 20730534  215429    55721     4.5  1367680764
# 14284838  148305      256     3.0  1204791700
